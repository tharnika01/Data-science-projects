# %%
import numpy as np
import pandas as pd

# %% [markdown]
# 1Q

# %%
pdata=pd.read_csv('/content/Patient_Data.csv')
bdata=pd.read_csv("/content/Billing_Data.csv")

# %%
pdata
# Out:
#    PatientID     Name   Department     Doctor  BillAmount  ReceptionistID  \
# 0        101    Alice   Cardiology  Dr. Smith      5000.0               1
# 1        102      Bob    Neurology   Dr. John         NaN               2
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0               1
# 3        104    David   Cardiology  Dr. Smith      6200.0               3
# 4        105      Eva  Dermatology   Dr. Rose         NaN               2
# 5        101    Alice   Cardiology  Dr. Smith      5000.0               1
#
#         CheckInTime
# 0  2023-01-10 09:00
# 1  2023-01-11 10:30
# 2  2023-01-12 11:00
# 3  2023-01-13 12:00
# 4  2023-01-14 08:45
# 5  2023-01-10 09:00

# %%
bdata
# Out:
#    PatientID  InsuranceCovered  FinalAmount
# 0        101              2000         3000
# 1        102              1500         3500
# 2        103              2500         5000
# 3        104              3000         3200
# 4        105              1000         4000

# %%
pdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   PatientID       6 non-null      int64
#  1   Name            6 non-null      object
#  2   Department      6 non-null      object
#  3   Doctor          6 non-null      object
#  4   BillAmount      4 non-null      float64
#  5   ReceptionistID  6 non-null      int64
#  6   CheckInTime     6 non-null      object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 468.0+ bytes

# %%
bdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   PatientID         5 non-null      int64
#  1   InsuranceCovered  5 non-null      int64
#  2   FinalAmount       5 non-null      int64
# dtypes: int64(3)
# memory usage: 252.0 bytes

# %% [markdown]
# 2Q

# %%
pdata[['PatientID',"Name",'Department','Doctor','BillAmount']]
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN
# 5        101    Alice   Cardiology  Dr. Smith      5000.0

# %% [markdown]
# 3Q

# %%
pdata.drop(columns=['ReceptionistID','CheckInTime'],axis=0,inplace=True)

# %%
pdata
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN
# 5        101    Alice   Cardiology  Dr. Smith      5000.0

# %% [markdown]
# 4Q

# %%
pdata.groupby(['Department'])['BillAmount'].sum()
# Out:
# Department
# Cardiology     16200.0
# Dermatology        0.0
# Neurology          0.0
# Orthopedics     7500.0
# Name: BillAmount, dtype: float64

# %% [markdown]
# 5Q

# %%
pdata.drop_duplicates()
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John         NaN
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose         NaN

# %% [markdown]
# 6Q

# %%
na_mean=pdata['BillAmount'].mean()
na_mean
# Out:
# np.float64(5925.0)

# %%
pdata['BillAmount'].fillna(pdata['BillAmount'].mean(), inplace=True)
# Out:
# /tmp/ipython-input-2485838885.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   pdata['BillAmount'].fillna(pdata['BillAmount'].mean(), inplace=True)

# %%
pdata
# Out:
#    PatientID     Name   Department     Doctor  BillAmount
# 0        101    Alice   Cardiology  Dr. Smith      5000.0
# 1        102      Bob    Neurology   Dr. John      5925.0
# 2        103  Charlie  Orthopedics    Dr. Lee      7500.0
# 3        104    David   Cardiology  Dr. Smith      6200.0
# 4        105      Eva  Dermatology   Dr. Rose      5925.0
# 5        101    Alice   Cardiology  Dr. Smith      5000.0

# %% [markdown]
# 7Q

# %%
data=pd.merge(bdata,pdata,on='PatientID', how='outer')
data
# Out:
#    PatientID  InsuranceCovered  FinalAmount     Name   Department     Doctor  \
# 0        101              2000         3000    Alice   Cardiology  Dr. Smith
# 1        101              2000         3000    Alice   Cardiology  Dr. Smith
# 2        102              1500         3500      Bob    Neurology   Dr. John
# 3        103              2500         5000  Charlie  Orthopedics    Dr. Lee
# 4        104              3000         3200    David   Cardiology  Dr. Smith
# 5        105              1000         4000      Eva  Dermatology   Dr. Rose
#
#    BillAmount
# 0      5000.0
# 1      5000.0
# 2      5925.0
# 3      7500.0
# 4      6200.0
# 5      5925.0

# %% [markdown]
# 8Q

# %%
add_data={"PatientID":[106, 107, 108, 109, 110],
    "InsuranceCovered":[3000,1000,3000,4000,2000],
    "FinalAmount":    [6612, 6257, 6564, 3882, 8485],
    "Name":           ["Julia", "Hannah", "Julia", "Grace", 'Maya'],
    "Department":     ["Neurology", "Dermatology", "Oncology", "Dermatology", "Cardiology"],
    "Doctor":         ["Dr. Kim", "Dr. Mehta", "Dr. Lee", "Dr. Lee", "Dr. Gupta"],
    "BillAmount":     [7093, 7220, 7500, 3976,3433]
          }

# %%
df=pd.DataFrame(add_data)
df
# Out:
#    PatientID  InsuranceCovered  FinalAmount    Name   Department     Doctor  \
# 0        106              3000         6612   Julia    Neurology    Dr. Kim
# 1        107              1000         6257  Hannah  Dermatology  Dr. Mehta
# 2        108              3000         6564   Julia     Oncology    Dr. Lee
# 3        109              4000         3882   Grace  Dermatology    Dr. Lee
# 4        110              2000         8485    Maya   Cardiology  Dr. Gupta
#
#    BillAmount
# 0        7093
# 1        7220
# 2        7500
# 3        3976
# 4        3433

# %%
data1=pd.concat([data,df], ignore_index=True)
data1
# Out:
#     PatientID  InsuranceCovered  FinalAmount     Name   Department     Doctor  \
# 0         101              2000         3000    Alice   Cardiology  Dr. Smith
# 1         101              2000         3000    Alice   Cardiology  Dr. Smith
# 2         102              1500         3500      Bob    Neurology   Dr. John
# 3         103              2500         5000  Charlie  Orthopedics    Dr. Lee
# 4         104              3000         3200    David   Cardiology  Dr. Smith
# 5         105              1000         4000      Eva  Dermatology   Dr. Rose
# 6         106              3000         6612    Julia    Neurology    Dr. Kim
# 7         107              1000         6257   Hannah  Dermatology  Dr. Mehta
# 8         108              3000         6564    Julia     Oncology    Dr. Lee
# 9         109              4000         3882    Grace  Dermatology    Dr. Lee
# 10        110              2000         8485     Maya   Cardiology  Dr. Gupta
#
#     BillAmount
# 0       5000.0
# ...

# %% [markdown]
# Droping the duplicate for clean data which helps in performing further anaysis

# %%
data1.drop_duplicates(inplace=True,ignore_index=True)
data1
# Out:
#    PatientID  InsuranceCovered  FinalAmount     Name   Department     Doctor  \
# 0        101              2000         3000    Alice   Cardiology  Dr. Smith
# 1        102              1500         3500      Bob    Neurology   Dr. John
# 2        103              2500         5000  Charlie  Orthopedics    Dr. Lee
# 3        104              3000         3200    David   Cardiology  Dr. Smith
# 4        105              1000         4000      Eva  Dermatology   Dr. Rose
# 5        106              3000         6612    Julia    Neurology    Dr. Kim
# 6        107              1000         6257   Hannah  Dermatology  Dr. Mehta
# 7        108              3000         6564    Julia     Oncology    Dr. Lee
# 8        109              4000         3882    Grace  Dermatology    Dr. Lee
# 9        110              2000         8485     Maya   Cardiology  Dr. Gupta
#
#    BillAmount
# 0      5000.0
# 1      5925.0
# 2      7500.0
# 3      6200.0
# 4      5925.0
# 5      7093.0
# ...

# %% [markdown]
# 9Q

# %%
billing_data = {
    "FinalAmount_dis": data1['FinalAmount']*0.9,
    'PaymentMode': np.random.choice(['Cash', 'Card', 'UPI'], size=len(data1))
}

# %%
df1=pd.DataFrame(billing_data)
df1
# Out:
#    FinalAmount_dis PaymentMode
# 0           2700.0         UPI
# 1           3150.0         UPI
# 2           4500.0        Card
# 3           2880.0         UPI
# 4           3600.0         UPI
# 5           5950.8        Card
# 6           5631.3        Card
# 7           5907.6        Cash
# 8           3493.8        Card
# 9           7636.5         UPI

# %%
final=pd.concat([data1,df1],axis=1)
final
# Out:
#    PatientID  InsuranceCovered  FinalAmount     Name   Department     Doctor  \
# 0        101              2000         3000    Alice   Cardiology  Dr. Smith
# 1        102              1500         3500      Bob    Neurology   Dr. John
# 2        103              2500         5000  Charlie  Orthopedics    Dr. Lee
# 3        104              3000         3200    David   Cardiology  Dr. Smith
# 4        105              1000         4000      Eva  Dermatology   Dr. Rose
# 5        106              3000         6612    Julia    Neurology    Dr. Kim
# 6        107              1000         6257   Hannah  Dermatology  Dr. Mehta
# 7        108              3000         6564    Julia     Oncology    Dr. Lee
# 8        109              4000         3882    Grace  Dermatology    Dr. Lee
# 9        110              2000         8485     Maya   Cardiology  Dr. Gupta
#
#    BillAmount  FinalAmount_dis PaymentMode
# 0      5000.0           2700.0         UPI
# ...

# %% [markdown]
# Final dataframe without duplicates and null values.
