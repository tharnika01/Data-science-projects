# %% [markdown]
# # 1 Question

# %%
list1=[0,2,4,6,8]
list1
# Out:
# [0, 2, 4, 6, 8]

# %%
list1.append(10)

# %%
list1
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
list1.extend([12,14])

# %%
list1
# Out:
# [0, 2, 4, 6, 8, 10, 12, 14]

# %%
list1.insert(1,16)

# %%
list1
# Out:
# [0, 16, 2, 4, 6, 8, 10, 12, 14]

# %%
list1.remove(8)

# %%
list1
# Out:
# [0, 16, 2, 4, 6, 10, 12, 14]

# %%
list1.pop(6)
# Out:
# 12

# %%
list1
# Out:
# [0, 16, 2, 4, 6, 10, 14]

# %%
list1.index(10)
# Out:
# 5

# %%
list1.count(14)
# Out:
# 1

# %%
list1.sort()

# %%
list1
# Out:
# [0, 2, 4, 6, 10, 14, 16]

# %%
list1.reverse()

# %%
list1
# Out:
# [16, 14, 10, 6, 4, 2, 0]

# %%
list1.clear()

# %%
list1
# Out:
# []

# %% [markdown]
# # 2 Question

# %%
tuple1=("john","bob","alice")

# %%
tuple1[1]="david" #because tuple is unmutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3046815449.py in <cell line: 0>()
# ----> 1 tuple1[1]="david" #because tuple is unmutable
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# the student name will not change and gives TypeError as 'tuple' object does not support item assignment because tuple is immutable

# %% [markdown]
# # 3 Question

# %%
set1={1,2,3,3,4,5,5,5}

# %%
set1
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# Returns the list without duplicates because set does not allow duplicates

# %% [markdown]
# # 4 Question

# %%
dict1={'name':'Anjali',
       'age':20,
       'city':'Hyderabad'}

# %%
dict1.update({"age":21})   # or dict1['age']=21

# %%
dict1['email']='anjali@gmail.com'

# %%
dict1
# Out:
# {'name': 'Anjali', 'age': 21, 'city': 'Hyderabad', 'email': 'anjali@gmail.com'}

# %% [markdown]
# # 5 Question

# %%
age=int(input("Enter your Age:"))
if age>=18:
  print("you are eligible to vote.")
else:
  print(f"you are not eligible to vote. After {18 - age} you are eligible to vote" )
# Out:
# Enter your Age:12
# you are not eligible to vote. After 6 you are eligible to vote

# %% [markdown]
# #6 Question

# %%
marks=int(input("Enter the marks:"))
if marks>=90:
  print('A')
elif marks>=75 and marks<=89:
  print('B')
elif marks>=50 and marks<=74:
  print('C')
else:
  print('Fail')
# Out:
# Enter the marks:78
# B

# %% [markdown]
# # 7 Question

# %%
num=int(input("Enter any number:"))
if num>0:
  if num%2==0:
   print(num,"is positive and even number")
  else:
    print(num,"is a positive number")
else:
  if num==0:
    print(num,"is zero")
  else:
      print(num,'is a negative number')
# Out:
# Enter any number:-19763
# -19763 is negative number

# %% [markdown]
# # 8 Question

# %%
import numpy as np
arr_scalar=np.array(5)
print(arr_scalar)
type(arr_scalar)
# Out:
# 5
# numpy.ndarray

# %%
arr_1d=np.array([1,2,3,4,5])
print(arr_1d)
# Out:
# [1 2 3 4 5]

# %%
arr_2d=np.array([[10,20,30],[40,50,60]])
arr_2d
# Out:
# array([[10, 20, 30],
#        [40, 50, 60]])

# %%
arr_rand=np.random.randint(0,100,size=(4))
arr_rand
# Out:
# array([96, 39, 24,  9])

# %%
arr_rand2=np.random.randint(1,100,size=(3,3))
arr_rand2
# Out:
# array([[43, 16, 23],
#        [33, 81, 90],
#        [61, 80, 86]])

# %%
import pandas as pd
df1=pd.DataFrame(arr_rand2,columns=("A","B","C"))
df1
# Out:
#     A   B   C
# 0  43  16  23
# 1  33  81  90
# 2  61  80  86

# %% [markdown]
# # 11 Question

# %%
import numpy as np
people = (
    ("Alice", 21, "Hyderabad", 50000),
    ("Bob", 25, "Delhi", 60000),
    ("Ian", 29, "Lucknow", 72000),
    ("David", 28, "Bangalore", np.nan),
    ("Eva", 22, "Chennai", 52000),
    ("Alice", 21, "Hyderabad", 50000),
    ("Grace", 24, "Kolkata", 58000),
    ("Helen", 26, "Jaipur", np.nan),
    ("Ian", 29, "Lucknow", 72000),
    ("Judy", 30, "Ahmedabad", np.nan)
)

# %%
people
# Out:
# (('Alice', 21, 'Hyderabad', 50000),
#  ('Bob', 25, 'Delhi', 60000),
#  ('Ian', 29, 'Lucknow', 72000),
#  ('David', 28, 'Bangalore', nan),
#  ('Eva', 22, 'Chennai', 52000),
#  ('Alice', 21, 'Hyderabad', 50000),
#  ('Grace', 24, 'Kolkata', 58000),
#  ('Helen', 26, 'Jaipur', nan),
#  ('Ian', 29, 'Lucknow', 72000),
#  ('Judy', 30, 'Ahmedabad', nan))

# %%
df2=pd.DataFrame(people, columns=("Name","Age","City","Salary"))
df2
# Out:
#     Name  Age       City   Salary
# 0  Alice   21  Hyderabad  50000.0
# 1    Bob   25      Delhi  60000.0
# 2    Ian   29    Lucknow  72000.0
# 3  David   28  Bangalore      NaN
# 4    Eva   22    Chennai  52000.0
# 5  Alice   21  Hyderabad  50000.0
# 6  Grace   24    Kolkata  58000.0
# 7  Helen   26     Jaipur      NaN
# 8    Ian   29    Lucknow  72000.0
# 9   Judy   30  Ahmedabad      NaN

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    10 non-null     object
#  1   Age     10 non-null     int64
#  2   City    10 non-null     object
#  3   Salary  7 non-null      float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 452.0+ bytes

# %%
df2.describe()
# Out:
#              Age        Salary
# count  10.000000      7.000000
# mean   25.500000  59142.857143
# std     3.439961   9581.728644
# min    21.000000  50000.000000
# 25%    22.500000  51000.000000
# 50%    25.500000  58000.000000
# 75%    28.750000  66000.000000
# max    30.000000  72000.000000

# %%
df2[["Name","City"]]
# Out:
#     Name       City
# 0  Alice  Hyderabad
# 1    Bob      Delhi
# 2    Ian    Lucknow
# 3  David  Bangalore
# 4    Eva    Chennai
# 5  Alice  Hyderabad
# 6  Grace    Kolkata
# 7  Helen     Jaipur
# 8    Ian    Lucknow
# 9   Judy  Ahmedabad

# %%
df2['Salary'].fillna(value=int(df2['Salary'].mean()),inplace=True)
df2
# Out:
# /tmp/ipython-input-152954126.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['Salary'].fillna(value=int(df2['Salary'].mean()),inplace=True)
#     Name  Age       City   Salary
# 0  Alice   21  Hyderabad  50000.0
# 1    Bob   25      Delhi  60000.0
# 2    Ian   29    Lucknow  72000.0
# 3  David   28  Bangalore  59142.0
# 4    Eva   22    Chennai  52000.0
# 5  Alice   21  Hyderabad  50000.0
# 6  Grace   24    Kolkata  58000.0
# 7  Helen   26     Jaipur  59142.0
# 8    Ian   29    Lucknow  72000.0
# ...

# %%
df2.drop_duplicates(ignore_index=True, inplace=True)

# %%
df2
# Out:
#     Name  Age       City   Salary
# 0  Alice   21  Hyderabad  50000.0
# 1    Bob   25      Delhi  60000.0
# 2    Ian   29    Lucknow  72000.0
# 3  David   28  Bangalore  59142.0
# 4    Eva   22    Chennai  52000.0
# 5  Grace   24    Kolkata  58000.0
# 6  Helen   26     Jaipur  59142.0
# 7   Judy   30  Ahmedabad  59142.0
